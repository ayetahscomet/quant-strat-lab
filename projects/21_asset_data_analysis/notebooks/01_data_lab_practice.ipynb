# %%
# /Users/deborahakintoye/GitHub/quant-strat-lab/projects/21_asset_data_analysis/notebooks/01_data_lab_practice.ipynb

import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Project root added to path:\n", PROJECT_ROOT)

import pandas as pd
import matplotlib.pyplot as plt

from src.data.load_data import load_asset_data
from src.analysis.compute_metrics import compute_returns, compute_summary_metrics
from src.visual.plots import plot_prices, plot_returns, plot_rolling_vol
# Out:
# Project root added to path:
#  /Users/deborahakintoye/GitHub/quant-strat-lab/projects/21_asset_data_analysis

# %%
price_df = load_asset_data()
price_df.head()

returns_df = compute_returns(price_df)
returns_df.head()
# Out:
#             EQ_Index  Commodity   FX_Rate
# Date
# 2018-01-02 -0.001464  -0.001744  0.003480
# 2018-01-03  0.008438   0.000475  0.000108
# 2018-01-04  0.019466   0.013503 -0.019676
# 2018-01-05 -0.002672   0.004526  0.001556
# 2018-01-08 -0.002672   0.018132  0.020946

# %%
price_df.info()
price_df.isna().sum()
price_df.describe()

returns_df.info()
returns_df.isna().sum()
returns_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2018-01-01 to 2024-12-31
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EQ_Index   1827 non-null   float64
#  1   Commodity  1827 non-null   float64
#  2   FX_Rate    1827 non-null   float64
# dtypes: float64(3)
# memory usage: 57.1 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2018-01-02 to 2024-12-31
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EQ_Index   1826 non-null   float64
#  1   Commodity  1826 non-null   float64
#  2   FX_Rate    1826 non-null   float64
# dtypes: float64(3)
# memory usage: 57.1 KB
#           EQ_Index    Commodity      FX_Rate
# count  1826.000000  1826.000000  1826.000000
# mean      0.000814     0.000251    -0.000372
# std       0.012473     0.018935     0.009335
# min      -0.040558    -0.056944    -0.029977
# ...

# %%
price_df.plot(figsize=(12,5), title="Asset Prices");
plt.show();

# %%
returns_df.plot(figsize=(12,5), title="Log Returns");
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plot_returns(returns_df)
#       2 returns_df.plot(figsize=(12,5), title="Log Returns");
#       3 plt.show();
#
# File ~/GitHub/quant-strat-lab/projects/21_asset_data_analysis/src/visual/plots.py:19, in plot_returns(return_df)
#      17 return_df.plot(ax = ax)
#      18 ax.set_title("Log Returns")
# ---> 19 fig.savefig(REPORTS_FIGURES / "returns.png")
#      20 plt.close(fig)
#
# TypeError: unsupported operand type(s) for /: 'module' and 'str'

# %%
returns_df.rolling(30).std().plot(figsize=(12,5), title="30-Day Rolling Volatility");
plt.show();

# %%
summary = compute_summary_metrics(price_df, returns_df)
summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 summary = compute_summary_metrics(price_df, returns_df)
#       2 summary
#
# File <string>:11, in compute_summary_metrics(price_df, return_df)
#
# File ~/GitHub/quant-strat-lab/projects/21_asset_data_analysis/src/analysis/compute_metrics.py:15, in max_drawdown(price_series)
#      13 def max_drawdown(price_series: pd.Series) -> pd.Series:
#      14     roll_max = price_series.cummax
# ---> 15     dd = (price_series - roll_max) / roll_max
#      16     return dd.min(), dd.idxmin()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# ...
