# %%
import os
file_path = f"/Users/deborahakintoye/GitHub/quant-strat-lab/projects/29_pure_vs_dirty_dispersion_trading_simulation/src/"
os.chdir(file_path)

import pandas as pd
import numpy as np
from data.generator import generate_returns

# %%
generate_returns()
# Out:
# Covariance Matrix Shape:    (50, 50)
# Diagonal Elements (Variances) Range from:   0.000257 to 0.000475
#
# Simulated Returns Shape (Days x Stocks):  (1000, 50)
#
# First 5 rows of simulated returns:
#     Stock_1   Stock_2   Stock_3   Stock_4   Stock_5   Stock_6   Stock_7  \
# 0  0.014033  0.009873  0.007914  0.030783  0.008979 -0.003747 -0.008900
# 1  0.034441 -0.024426  0.034658  0.017529  0.027166 -0.013515  0.022146
# 2 -0.002174  0.021919  0.013176 -0.029567 -0.002807 -0.019003 -0.027347
# 3 -0.015694 -0.006628  0.034592 -0.026649  0.016923  0.011879 -0.008823
# 4  0.009892  0.042568  0.003654  0.018613  0.014703  0.011742 -0.000125
#
#     Stock_8   Stock_9  Stock_10  ...  Stock_41  Stock_42  Stock_43  Stock_44  \
# 0 -0.004288 -0.005437  0.018856  ... -0.019550  0.012837  0.019846  0.015463
# 1 -0.028366 -0.008013 -0.009108  ...  0.028879 -0.004708  0.015384 -0.015821
# 2  0.016492  0.012890 -0.009383  ...  0.005302 -0.014834 -0.014345  0.035723
# ...
