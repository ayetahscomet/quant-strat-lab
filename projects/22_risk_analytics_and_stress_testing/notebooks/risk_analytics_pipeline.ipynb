# %%
# notebooks/risk_analytics_pipeline.ipynb

import os

LOCATION = "workspaces"
os.chdir(f"/{LOCATION}/quant-strat-lab/projects/22_risk_analytics_and_stress_testing/")
print(os.getcwd())

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.generator import generate_synthetic_universe
from src.pnl.aggregator import compute_nav
from src.risk.var_es import historical_var_es, parameteric_var_es, montecarlo_var_es
from src.risk.stress import return_shock, vol_shock, corr_breakdown
from src.analysis.diagnostics import plot_nav, plot_return_distribution
# Out:
# /workspaces/quant-strat-lab/projects/22_risk_analytics_and_stress_testing
