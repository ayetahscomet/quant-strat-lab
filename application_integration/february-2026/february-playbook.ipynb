# %% [markdown]
# # **Akinto.io: February Week 1 Launch Readiness Notebook**

# %% [markdown]
# ## Week 1 Objectives
#
# - Platform robustness under light traffic
# - Airtable performance & limits
# - Analytics correctness
# - Abuse / edge‑case handling
# - Mobile UX polish
# - Legal & privacy readiness

# %% [markdown]
# ## Daily Operating Log
#
# ### Day:    Sunday
#
# **Date**:   01-February-2026
#
# **What changed in code**:   Updated hint logging logic
#
# **Bugs discovered**:
# -   Discovered issues relating to hint generation
# -   Too many fillers relating in the daliy analytics page
#
#
# **Bugs fixed**:             Hint logic updated
#
# **Metrics observed**:       Cleaner logs
#
# **Notes**:
#
# ![image.png](attachment:image.png)
#
#
# ### Day:
#
# **Date**:
#
# **What changed in code**:
#
# **Bugs discovered**:
#
# **Bugs fixed**:
#
# **Metrics observed**:
#
# **Notes**:

# %% [markdown]
# ## Core Test Matrix
#
# For each test record:
# - Result: PASS / FAIL
# - Screenshot or console logs
#
#
#
# | Test Metric    |   Day 1   |   Day 2   |   Day 3   |   Day 4   |   Day 5   |   Day 6   |   Day 7   |
# |-----------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|
# | Fresh user journey          |           |           |           |           |           |           |           |
# | Return visit          |           |           |           |           |           |           |           |
# | Lockout enforcement          |           |           |           |           |           |           |           |
# | Exit early flow          |           |           |           |           |           |           |           |
# | Success summary          |           |           |           |           |           |           |           |
# | Opens/closes correctly          |           |           |           |           |           |           |           |
# | Timezone accuracy          |           |           |           |           |           |           |           |
# | Refresh at midnight          |           |           |           |           |           |           |           |
# | Completion % correct          |           |           |           |           |           |           |           |
# | Accuracy % correct          |           |           |           |           |           |           |           |
# | Pace percentile          |           |           |           |           |           |           |           |
# | Global averages           |           |           |           |           |           |           |           |
# | **Fixes required**          |           |           |           |           |           |           |           |
#
#
# **Day 1 Assessments + Updates:**
#
# **Day 2 Assessments + Updates:**
#
# **Day 3 Assessments + Updates:**
#
# **Day 4 Assessments + Updates:**
#
# **Day 5 Assessments + Updates:**
#
# **Day 6 Assessments + Updates:**
#
# **Day 7 Assessments + Updates:**

# %% [markdown]
# ## Airtable Stress Testing
#
# ### Tests to run
# - 100 simulated users
# - 1k rows added
# - Query latency
# - API rate limits
# - Error handling
#
# ### Observations

# %%
# Optional: paste load‑test scripts here

# %% [markdown]
# ## Mobile UX Audit
#
# |   UI Metrics    | Overflow    |   Buttons Tapable |   Rings Visible   |   Cards Stacked Cleanly | OVERALL PASS/FAIL   |   Notes   |
# |-----------------|-------------|-------------------|-------------------|-------------------------|---------------------|------------|
# | iOS Safari                 |             |                   |                   |                         |                     |           |
# | Chrome Android                |             |                   |                   |                         |                     |           |
# | Small screens (<390px)                 |             |                   |                   |                         |                     |           |
# | Tablet                |             |                   |                   |                         |                     |           |

# %% [markdown]
# ## Security & Privacy
#
# - **API keys server‑side**
#
# - **Rate limiting**
#
# - **CAPTCHA?**
#
# - **GDPR notice**
#
# - **Cookie banner**
#
# - **Data deletion path**

# %% [markdown]
# ## Launch Readiness Scorecard
#
# | Area | Status | Notes |
# |------|-------|------|
# | Gameplay | | |
# | Airtable | | |
# | Analytics | | |
# | Mobile | | |
# | Security | | |
# | Copywriting | | |

# %% [markdown]
# ## QR Pilot Decision Gate
#
# Greenlight criteria:
# - 0 critical bugs
# - <300ms API latency
# - No Airtable errors
# - Analytics stable
# - Mobile clean
#
# **Decision:** GO / HOLD

# %% [markdown]
# ## **WEEK-1 MASTER TEST LIST**
#
#
# ### **GAMEPLAY RELIABILITY**
#
# - [ ] Run each at least 3 times:
#
# - [ ] Start → finish clean run
#
# - [ ] Start → wrong answers only → lockout
#
# - [ ] Start → exit early → return later
#
# - [ ] Refresh page mid-window
#
# - [ ] Open in two tabs
#
# - [ ] Open on phone + laptop simultaneously
#
# - [ ] Lose internet mid-submit
#
# - [ ] Submit same answer twice
#
# - [ ] Type fast → spam submit
#
# - [ ] Hint + wrong + correct combos
#
#
# ### **ANALYTICS ACCURACY**
#
# Manually calculate:
#
# - [ ] Completion %
#
# - [ ] Accuracy %
#
# - [ ] Duplicate count
#
# - [ ] Pace time
#
# - [ ] Windows played
#
# - [ ] Attempt count
#
# - [ ] Compare to dashboard
#
# If even one differs → bug
#
# ### **AIRTABLE STRESS**
#
# Test:
#
# - [ ] 500 rows in one day
#
# - [ ] Same user multiple days
#
# - [ ] Same day multiple attempts
#
# - [ ] Missing fields
#
# - [ ] API timeout
#
# - [ ] Partial write
#
# - [ ] Duplicate prevention
#
# Indexing on:
#
# - [ ] userId
#
# - [ ] dateKey
#
# - [ ] country
#
# Check:
#
# - [ ] Query speed < 300ms
#
# - [ ] No corrupted rows
#
# - [ ] No runaway table growth
#
# ### **PERFORMANCE**
#
# Use DevTools:
#
# - [ ] Mobile throttle
#
# - [ ] Slow 3G test
#
# - [ ] First paint < 3s
#
# - [ ] Analytics page < 4s
#
# - [ ] API payload size
#
# - [ ] Chart rendering time
#
# ### **SECURITY HYGIENE (EARLY STAGE)**
#
# We don’t need full SOC-2 yet - but:
#
# - [ ] Server-side only tokens ✔
#
# - [ ] Env vars used ✔
#
# - [ ] Input sanitised ✔
#
# - [ ] Simple rate limiting ✔
#
# - [ ] Bot abuse prevention ✔
#
# - [ ] UUID cannot be spoofed easily ✔
#
# - [ ] Country code validated ✔
