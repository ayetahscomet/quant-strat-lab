# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

CURR_DIR = os.path.dirname(os.path.abspath(__file__))

from src.features.carry import compute_carry, compute_forward_prices

compute_forward_prices(domestic_rate = 0.02, foreign_rate = 0.07)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 import matplotlib.pyplot as plt
#       4 import os
# ----> 6 CURR_DIR = os.path.dirname(os.path.abspath(__file__))
#       8 from src.features.carry import compute_carry, compute_forward_prices
#      10 compute_forward_prices(domestic_rate = 0.02, foreign_rate = 0.07)
#
# NameError: name '__file__' is not defined
