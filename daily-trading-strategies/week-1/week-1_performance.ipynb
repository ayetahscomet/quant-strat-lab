# %% [markdown]
# # Weekly Trade Performance (5-9 Jan 2026)
#
# The first trading week of January was used to translate five macro news items into tactical trade expressions across equities, FX, and cross-asset relative value. The week demonstrated a consistent process, clean thesis articulation, and disciplined horizon management. Performance across the five simulated trades was mixed positive, with notable strengrth in macro-driven relative value spreads and weaker results in single-stock directional trades or factor heavy expressions.
#
# ---
#
# ##  Performance Overview
#
# Across all 5 ideas:
#
# | Dimension             | Assessment                    |
# |-----------------------|-------------------------------|
# | Idea Quality          | High                          |
# | Risk Discipline       | Present and improving         |
# | Factor Awareness      | Emerging, mixed execution     |
# | PnL Outcomes          | Mixed-positive                |
# | Process Quality       | Very strong for early phase   |
#
# ### Top Performer
# **EM AI Hardware vs Software Spread** - strong structural theme, clean RV, realised +15% on first sample.
#
# ### Notable Positive Contributors:
# -   **Southern Europe vs Core Europe (Equity RV)** → +70bps avg, 71% win rate
# -   **Long CNY vs Short EUR (FX Fundamentals)** → +140 bps
#
# ### Underperformers:
# -   **US vs EU Oil Majors Spread** → Slightly negative, factor-contaminated
# -   **Long Live Nation** → Mild negative; horizon mismatch with simulation window
#
# ---
#
# ##  Key Takeaways from PnL Attribution
#
# ### Positive Trades Shared 3 Features:
# 1. Policy or fundamentals-based catalysts
# 2. Relative value construction (long vs short)
# 3. De-risked beta exposure
#
# Examples:
# - Europe RV (policy + fiscal + growth)
# - Hardware Spread (cycle + valuation + capex)
# - CNH/EUR (real FX + flows + geopolitics)
#
# ---
#
# ## Negative Trades Shared 2 Features:
# 1. **Feature contamination** (Oil Beta, Risk-On/Off)
# 2. **Horizon mismatch** (live entertainment thesis too long-term)
#
# ---
#
# ##  Pattern Identification
#
# I seem to be strongest on macro-driven spreads with cross-border divergence and fundamental catalysts.
#
# *"I ran five trades off macro headlines. The strongest results cam from macro-relative-value spreads - Southern European equities versus core Europe, EM AI hardware vs software, and CNH vs EUR - all positive with clean catalysts and well aligned horizons. The oil majors RV idea was conceptually correct but contaminated by crude beta and the Live Nation long was directionally vulnerable due to horizon mismatch. The main takeaways are that my edge is in macro RV with cross-border catalysts, and I need to improve factor neurralisation and exection horizon control. I've already adapted my template to incorporate factor matrices, compounding stops, trade taxonomy, and blotter exports."*
