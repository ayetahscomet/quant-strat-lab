# %% [markdown]
# # Weekly Trade Performance (12-17 Jan 2026)
#
# The second trading week of January converted five macro headlines into FX-heavy, cross-asset relative value expressions centred on policy regime shifts, geopolitical credibility risk, and cross-border divergence. The process showed continued strength in idea formation, RV structuring, catalyst alignment, and horizon discipline.
# Performance across the five simulated trades showed positive expectancy, with notable strength in macro RV spreads and weaker results where instrument purity or factor contamination reduced the ability to isolate the intended thesis.
#
# ---
#
# ##  Performance Overview
#
# Across all 5 ideas:
#
# | Dimension             | Assessment                    |
# |-----------------------|-------------------------------|
# | Idea Quality          | High (policy & geopolitical focused)                          |
# | Risk Discipline       | Present and consistent        |
# | Factor Awareness      | Stronger, still developing     |
# | PnL Outcomes          | Slight-positive, convex skew                |
# | Process Quality       | Institutional for this stage   |
#
# ### Top Performer
# **USD Credibility Short vs Safe-Havens (12 Jan)** — diversified safe-haven basket, clean thesis, +19bps avg, 57% win rate, low stop-outs
#
# ### Notable Positive Contributors:
# -   **DXJ (Japan Hedged EQ) vs JGB Proxy (14 Jan)** → +70bps avg, convex, catalyst-driven
# -   **Long CAD/CNH vs Short USD (17 Jan)** → +10bps avg, trade-detente catalyst worked structurally → +140 bps
#
# ### Underperformers:
# -   **EUR vs GBP Stagflation Divergence (13 Jan)** → USD contamination + wrong historical regime
# -   **Korea (EWY) vs Germany (FXE) (16 Jan)** → semiconductor equity vol dominated FX thesis
#
# ---
# ##  PnL Performance Metrics
#
# Using backtested sample PnLs (equal-weighted model book):
#
# - Expected Weekly PnL: +9bps
# - Return Distribution: positively skewed
# - Hit Rate (across 5 trades): 3/5 positive expectancy
# - Convexity: Present in 2 trades (Japan & Korea themes)
# - Left-Tail Profile: Limited — no catastrophic negative tail
# - Capital Preservation: Achieved (no model blow-ups, stops triggered appropriately)
#
# **Interpretation:**
#
# The book behaved like a well-constructed discretionary macro RV sleeve: small positive carry, convex right tail, low left tail.
#
# ---
#
# ##  Key Takeaways from PnL Attribution
#
# ### Positive Trades Shared 3 Features:
# 1. Policy or geopolitics-based catalysts
# 2. Relative value construction (hedged beta)
# 3. Cross-border divergence with identifiable windows
#
# Examples:
# - USD credibility short (Fed independence risk)
# - Takaichi trade (JP EQ vs JGB) (fiscal–monetary divergence)
# - CAD/CNH detente basket (tariff & trade regime shift)
#
# ---
#
# ## Negative Trades Shared 2 Features:
# 1. Instrument purity issues (EWY ≠ KRW, FXB/FXE USD contamination)
# 2. Regime mismatch (EURGBP backtest reflects 2020–2025 dynamics, not 2026 forward thesis)
#
# Examples:
# - EURGBP reflected historical ECB hiking lag, not UK stagflation
# - KRW basket reflected semiconductor cycle, not currency policy
#
# ---
#
# ##  Pattern Identification
#
# Two patterns emerged clearly:
#
# **(i) Edge Exists in Macro RV with Policy Divergence**
#
# I consistently added value where:
# - governments intervened (US vs Fed, Japan fiscal, China/Canada detente)
# - currencies reflected policy credibility, not risk sentiment
# - spreads decomposed fundamentals from beta
#
# **(ii) Weakness Exists in Structural Instrument Selection**
#
# Signals were weakened by:
#
# - USD beta leakage (FXE/FXB)
# - Equity-contaminated FX proxies (EWY)
# - Wrong volatility calibration (GBP stops too tight for FX macro window)
#
#
# *“I ran five macro RV trades. My strongest results came from USD credibility, Japan’s fiscal divergence, and CAD/CNH trade détente — all of which monetise policy differentials with clear catalysts. The weaker performers were not macro errors, but instrument purity and regime mismatch issues: EURGBP was contaminated by USD and backtested in the wrong regime, and EWY introduced semiconductor equity beta into what should have been a KRW trade. The key takeaway is that my edge is in macro-relative-value with cross-border catalysts, and I need to improve instrument purity, factor neutralisation, and horizon calibration. I’ve begun addressing this by prioritising direct crosses over USD ETFs, tightening catalyst windows, and adjusting stops to vol regimes.”*
